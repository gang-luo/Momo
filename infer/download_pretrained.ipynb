# %% [markdown]
# # Download NovoMolGen checkpoints and datasets to pretrained_mol/

# %%
from huggingface_hub import snapshot_download
from pathlib import Path
root = Path('pretrained_mol')
root.mkdir(exist_ok=True, parents=True)
repos = [
 'chandar-lab/NovoMolGen_32M_SMILES_AtomWise',
 'chandar-lab/NovoMolGen_157M_SMILES_AtomWise',
 'chandar-lab/NovoMolGen_300M_SMILES_AtomWise',
 'chandar-lab/ZINC_250k',
 'chandar-lab/ZINC_22',
 'chandar-lab/zinc_scaffold',
 'chandar-lab/zinc_random',
]
for repo in repos:
    local_dir = root / repo.split('/')[-1]
    snapshot_download(repo_id=repo, repo_type='model' if 'NovoMolGen' in repo else 'dataset', local_dir=str(local_dir), local_dir_use_symlinks=False)
    print('downloaded', repo, '->', local_dir)
# Out:
# Fetching 93 files:   0%|          | 0/93 [00:00<?, ?it/s]
# downloaded chandar-lab/NovoMolGen_32M_SMILES_AtomWise -> pretrained_mol/NovoMolGen_32M_SMILES_AtomWise
# Fetching 63 files:   0%|          | 0/63 [00:00<?, ?it/s]
# downloaded chandar-lab/NovoMolGen_157M_SMILES_AtomWise -> pretrained_mol/NovoMolGen_157M_SMILES_AtomWise
# Fetching 69 files:   0%|          | 0/69 [00:00<?, ?it/s]
# downloaded chandar-lab/NovoMolGen_300M_SMILES_AtomWise -> pretrained_mol/NovoMolGen_300M_SMILES_AtomWise
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# downloaded chandar-lab/ZINC_250k -> pretrained_mol/ZINC_250k
# Fetching 1232 files:   0%|          | 0/1232 [00:00<?, ?it/s]
# train-00650-of-01212.parquet:  74%|#######4  | 147M/198M [00:00<?, ?B/s]
# train-00655-of-01212.parquet:   0%|          | 0.00/198M [00:00<?, ?B/s]
# train-00656-of-01212.parquet:   0%|          | 0.00/198M [00:00<?, ?B/s]
# train-00654-of-01212.parquet:   0%|          | 0.00/198M [00:00<?, ?B/s]
# ...

# %%
print("a")
# Out:
# a
